# %%
# !pip install meteocalc
# Out:
# Requirement already satisfied: meteocalc in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#!cp /content/drive/MyDrive/ashrae.zip ashrae.zip
#!unzip -q ashrae.zip

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import gc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.figure_factory as ff

from IPython.core.pylabtools import figsize
from plotly.offline import init_notebook_mode,iplot,plot
# %matplotlib inline
init_notebook_mode(connected=True)
plt.style.use("ggplot")
from sklearn.utils import shuffle

from sklearn.preprocessing import  LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

from keras.models import load_model
from keras.models import Model 
from keras.layers import Input, Dense, Lambda
from keras.layers import Embedding, Flatten, Dropout, Add, Activation
from keras.optimizers import Adam 
from keras.callbacks import ModelCheckpoint,EarlyStopping
import keras.backend as K

# importer les fichiers .py sur le notebook
# %run utils.py
# %run feature_enginering.py
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
building = pd.read_csv('/content/building_metadata.csv')
weather = pd.read_csv('/content/weather_train.csv')
train = pd.read_csv('/content/train.csv')

train.loc[(train.meter == 0),'meter_reading'] = train['meter_reading'] * 0.2931 # convertir du kwh vers kbtu

# %%
building = reduce_mem_usage(building)
weather  = reduce_mem_usage(weather)
train = reduce_mem_usage(train)

# %%
building = prepare_building_data(building)
weather = prepare_weather_data(weather)
train  = time_features(train)

# %%
def join_data(data , weather_data , building_data):

    data = data.merge(building_data, on = 'building_id' , how='left')
    data = data.merge(weather_data , on = ['site_id','timestamp'], how= 'left')
    data = shuffle(data, random_state=0)

    return data

# %%
train = join_data(train , weather , building)

train['log_meter_reading'] = np.log(train['meter_reading'] + 1)
train['month_group'] = train['month_group'] - 1

train = train.drop(['meter_reading'] , axis= 1)

train  = reduce_mem_usage(train)
del weather, building
gc.collect()
# Out:
# 26

# %%
print(len(train.columns))
print(train.columns)
print(train.shape)
# Out:
# 24
# Index(['building_id', 'meter', 'timestamp', 'hour', 'dayofweek', 'month_group',
#        'site_id', 'primary_use', 'square_feet', 'year_built', 'floor_count',
#        'air_temperature', 'cloud_coverage', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'relative_humidity', 'feels_like', 'city', 'country',
#        'is_holiday', 'log_meter_reading'],
#       dtype='object')
# (20216100, 24)

# %%
for col in train.columns:
  if train[col].isnull().values.any():
    print(col , 'il y a', train[col].isnull().values.sum() , ' Nan ')
# Out:
# air_temperature il y a 90495  Nan
# cloud_coverage il y a 90495  Nan
# dew_temperature il y a 90495  Nan
# precip_depth_1_hr il y a 90495  Nan
# sea_level_pressure il y a 90495  Nan
# wind_direction il y a 90495  Nan
# wind_speed il y a 90495  Nan
# relative_humidity il y a 90495  Nan
# feels_like il y a 90495  Nan
# city il y a 90495  Nan
# country il y a 90495  Nan
# is_holiday il y a 90495  Nan

# %%
cols_to_drop = ['year_built' , 'floor_count' , 'timestamp']

cols_to_scale = ['square_feet' , 'air_temperature' , 'dew_temperature' ,
                 'wind_speed', 'cloud_coverage', 'sea_level_pressure', 'wind_direction',
                 'relative_humidity', 'feels_like']

cols_to_encode = ['primary_use' , 'city' , 'country']

cols_to_fill_median = ['air_temperature', 'cloud_coverage', 'dew_temperature', 'precip_depth_1_hr',
                       'sea_level_pressure','wind_direction' , 'wind_speed', 'relative_humidity' ,
                       'feels_like']

cols_to_fill_categ = ['city' , 'country' , 'is_holiday']


Filler = Data_Filler(cols_to_fill_median,
                     cols_to_fill_categ)

Filler.fit(train)
train = Filler.transform(train)

ScalerEncoder = Data_Scaler_Encoder(cols_to_scale ,
                                    cols_to_drop , 
                                    cols_to_encode)
ScalerEncoder.fit(train)
train = ScalerEncoder.transform(train)

# %%
def residual_block(input_x, nodes):
    d1 = Dense(nodes,activation='relu')(input_x)
    d2 = Dense(nodes,activation='relu')(d1)

    projected_x = Dense(nodes,activation='relu')(input_x)

    add = Add()([projected_x , d2])
    return add

def create_model(data , categorical_vars , numerical_vars):
    categ_inputs = []
    embed_layers = []  
    for col in categorical_vars:
        num_classes = len(np.unique(data[col]))

        input_x = Input(shape = [1] , name = col)
        categ_inputs.append(input_x)

        embed_x = Embedding(num_classes, 2)(input_x)
        embed_layers.append(embed_x)

    num_inputs = []
    for col in numerical_vars:
        num_inputs.append(Input(shape=[1] , name = col))

    concat_emb = K.concatenate([Flatten()(emb_layer) for emb_layer in embed_layers])

    d1 = residual_block(concat_emb , 512)
    main = K.concatenate(num_inputs+[d1])

    d2 = residual_block(main , 512)
    d3 = residual_block(d2 , 256)
    d4 = residual_block(d3 , 8)

    df = Dense(4 , name='second_to_last_layer')(d3)

    output = Dense(1)(df)
    model  = Model(categ_inputs + num_inputs, output)

    return model 

def rmse(y_true, y_pred):
    """ root_mean_squared_error """
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
train.head()
# Out:
#           building_id  meter  hour  ...  country  is_holiday  log_meter_reading
# 11990877          774      1     8  ...        3         0.0           3.614396
# 15256244          206      0    14  ...        3         0.0           4.209454
# 18401495         1269      0    10  ...        3         0.0           2.241073
# 15573710          951      0     4  ...        3         1.0           3.529892
# 6515439           656      0    21  ...        2         0.0           2.359378
#
# [5 rows x 21 columns]

# %%
categorical_vars = ['building_id' , 'meter', 'hour', 'dayofweek' , 'month_group', 'site_id' , 
                    'primary_use', 'city', 'country', 'is_holiday']
                    
numerical_vars = ['square_feet', 'air_temperature', 'cloud_coverage', 'dew_temperature',
                  'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed', 
                  'relative_humidity' , 'feels_like']

target_var = 'log_meter_reading'

model = create_model(train, categorical_vars, numerical_vars)

# %%
y = train[target_var].values
y = y.reshape((len(y) , 1))

train = train.drop( [target_var] , axis = 1)

co_vars = categorical_vars + numerical_vars
train = train[co_vars].values

train = [ train[:,i].flatten() for i in range(len(train[0,:])) ]

# %%
checkpoint = ModelCheckpoint( '/content/drive/MyDrive/model_ann.h5', 
                                monitor='rmse', 
                                verbose=1, 
                                save_best_only=True, 
                                mode='min')

early_stopping = EarlyStopping(patience = 5 ,monitor = "rmse")
callbacks_list = [checkpoint , early_stopping]

model.compile(optimizer = Adam(lr=1e-4), loss = 'mse',  metrics = [rmse])
history = model.fit(train, y, epochs = 70, batch_size = 1024, callbacks = callbacks_list)
# Out:
# Epoch 1/70
# 19743/19743 [==============================] - 176s 9ms/step - loss: 1.3316 - rmse: 1.1176
#
# Epoch 00001: rmse improved from inf to 0.98098, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 2/70
# 19743/19743 [==============================] - 169s 9ms/step - loss: 0.7465 - rmse: 0.8618
#
# Epoch 00002: rmse improved from 0.98098 to 0.84488, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 3/70
# 19743/19743 [==============================] - 177s 9ms/step - loss: 0.6463 - rmse: 0.8018
#
# Epoch 00003: rmse improved from 0.84488 to 0.79150, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 4/70
# 19743/19743 [==============================] - 164s 8ms/step - loss: 0.5837 - rmse: 0.7619
#
# Epoch 00004: rmse improved from 0.79150 to 0.75551, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 5/70
# 19743/19743 [==============================] - 164s 8ms/step - loss: 0.5421 - rmse: 0.7341
#
# Epoch 00005: rmse improved from 0.75551 to 0.72929, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 6/70
# 19743/19743 [==============================] - 165s 8ms/step - loss: 0.5117 - rmse: 0.7131
#
# Epoch 00006: rmse improved from 0.72929 to 0.70895, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 7/70
# 19743/19743 [==============================] - 162s 8ms/step - loss: 0.4857 - rmse: 0.6946
#
# Epoch 00007: rmse improved from 0.70895 to 0.69166, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 8/70
# 19743/19743 [==============================] - 161s 8ms/step - loss: 0.4642 - rmse: 0.6790
#
# Epoch 00008: rmse improved from 0.69166 to 0.67682, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 9/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.4466 - rmse: 0.6659
#
# Epoch 00009: rmse improved from 0.67682 to 0.66419, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 10/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.4311 - rmse: 0.6543
#
# Epoch 00010: rmse improved from 0.66419 to 0.65295, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 11/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.4170 - rmse: 0.6434
#
# Epoch 00011: rmse improved from 0.65295 to 0.64261, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 12/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.4055 - rmse: 0.6345
#
# Epoch 00012: rmse improved from 0.64261 to 0.63376, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 13/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.3942 - rmse: 0.6256
#
# Epoch 00013: rmse improved from 0.63376 to 0.62572, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 14/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.3854 - rmse: 0.6184
#
# Epoch 00014: rmse improved from 0.62572 to 0.61830, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 15/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.3763 - rmse: 0.6111
#
# Epoch 00015: rmse improved from 0.61830 to 0.61139, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 16/70
# 19743/19743 [==============================] - 158s 8ms/step - loss: 0.3690 - rmse: 0.6051
#
# Epoch 00016: rmse improved from 0.61139 to 0.60509, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 17/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.3607 - rmse: 0.5983
#
# Epoch 00017: rmse improved from 0.60509 to 0.59926, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 18/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.3543 - rmse: 0.5929
#
# Epoch 00018: rmse improved from 0.59926 to 0.59350, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 19/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.3475 - rmse: 0.5872
#
# Epoch 00019: rmse improved from 0.59350 to 0.58825, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 20/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3421 - rmse: 0.5826
#
# Epoch 00020: rmse improved from 0.58825 to 0.58318, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 21/70
# 19743/19743 [==============================] - 152s 8ms/step - loss: 0.3370 - rmse: 0.5781
#
# Epoch 00021: rmse improved from 0.58318 to 0.57860, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 22/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.3316 - rmse: 0.5735
#
# Epoch 00022: rmse improved from 0.57860 to 0.57384, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 23/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3252 - rmse: 0.5680
#
# Epoch 00023: rmse improved from 0.57384 to 0.56962, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 24/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3202 - rmse: 0.5636
#
# Epoch 00024: rmse improved from 0.56962 to 0.56540, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 25/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3151 - rmse: 0.5591
#
# Epoch 00025: rmse improved from 0.56540 to 0.56122, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 26/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3123 - rmse: 0.5565
#
# Epoch 00026: rmse improved from 0.56122 to 0.55730, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 27/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.3074 - rmse: 0.5521
#
# Epoch 00027: rmse improved from 0.55730 to 0.55333, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 28/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.3035 - rmse: 0.5487
#
# Epoch 00028: rmse improved from 0.55333 to 0.54969, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 29/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2993 - rmse: 0.5448
#
# Epoch 00029: rmse improved from 0.54969 to 0.54616, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 30/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2954 - rmse: 0.5412
#
# Epoch 00030: rmse improved from 0.54616 to 0.54309, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 31/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2908 - rmse: 0.5370
#
# Epoch 00031: rmse improved from 0.54309 to 0.53951, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 32/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2885 - rmse: 0.5349
#
# Epoch 00032: rmse improved from 0.53951 to 0.53654, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 33/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2848 - rmse: 0.5314
#
# Epoch 00033: rmse improved from 0.53654 to 0.53333, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 34/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2823 - rmse: 0.5290
#
# Epoch 00034: rmse improved from 0.53333 to 0.53053, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 35/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2788 - rmse: 0.5258
#
# Epoch 00035: rmse improved from 0.53053 to 0.52777, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 36/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2758 - rmse: 0.5229
#
# Epoch 00036: rmse improved from 0.52777 to 0.52492, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 37/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2733 - rmse: 0.5205
#
# Epoch 00037: rmse improved from 0.52492 to 0.52229, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 38/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2696 - rmse: 0.5170
#
# Epoch 00038: rmse improved from 0.52229 to 0.51969, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 39/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2677 - rmse: 0.5152
#
# Epoch 00039: rmse improved from 0.51969 to 0.51729, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 40/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2652 - rmse: 0.5127
#
# Epoch 00040: rmse improved from 0.51729 to 0.51500, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 41/70
# 19743/19743 [==============================] - 153s 8ms/step - loss: 0.2624 - rmse: 0.5100
#
# Epoch 00041: rmse improved from 0.51500 to 0.51228, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 42/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2605 - rmse: 0.5082
#
# Epoch 00042: rmse improved from 0.51228 to 0.51014, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 43/70
# 19743/19743 [==============================] - 157s 8ms/step - loss: 0.2582 - rmse: 0.5059
#
# Epoch 00043: rmse improved from 0.51014 to 0.50793, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 44/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2556 - rmse: 0.5033
#
# Epoch 00044: rmse improved from 0.50793 to 0.50577, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 45/70
# 19743/19743 [==============================] - 158s 8ms/step - loss: 0.2535 - rmse: 0.5013
#
# Epoch 00045: rmse improved from 0.50577 to 0.50362, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 46/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.2514 - rmse: 0.4992
#
# Epoch 00046: rmse improved from 0.50362 to 0.50183, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 47/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.2500 - rmse: 0.4978
#
# Epoch 00047: rmse improved from 0.50183 to 0.49981, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 48/70
# 19743/19743 [==============================] - 158s 8ms/step - loss: 0.2480 - rmse: 0.4958
#
# Epoch 00048: rmse improved from 0.49981 to 0.49812, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 49/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.2457 - rmse: 0.4935
#
# Epoch 00049: rmse improved from 0.49812 to 0.49618, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 50/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.2440 - rmse: 0.4918
#
# Epoch 00050: rmse improved from 0.49618 to 0.49430, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 51/70
# 19743/19743 [==============================] - 159s 8ms/step - loss: 0.2418 - rmse: 0.4896
#
# Epoch 00051: rmse improved from 0.49430 to 0.49237, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 52/70
# 19743/19743 [==============================] - 157s 8ms/step - loss: 0.2404 - rmse: 0.4881
#
# Epoch 00052: rmse improved from 0.49237 to 0.49085, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 53/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2389 - rmse: 0.4866
#
# Epoch 00053: rmse improved from 0.49085 to 0.48916, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 54/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2372 - rmse: 0.4848
#
# Epoch 00054: rmse improved from 0.48916 to 0.48722, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 55/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2359 - rmse: 0.4835
#
# Epoch 00055: rmse improved from 0.48722 to 0.48558, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 56/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2342 - rmse: 0.4818
#
# Epoch 00056: rmse improved from 0.48558 to 0.48438, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 57/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2331 - rmse: 0.4807
#
# Epoch 00057: rmse improved from 0.48438 to 0.48268, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 58/70
# 19743/19743 [==============================] - 157s 8ms/step - loss: 0.2308 - rmse: 0.4783
#
# Epoch 00058: rmse improved from 0.48268 to 0.48111, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 59/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2291 - rmse: 0.4765
#
# Epoch 00059: rmse improved from 0.48111 to 0.47969, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 60/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2283 - rmse: 0.4756
#
# Epoch 00060: rmse improved from 0.47969 to 0.47816, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 61/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2268 - rmse: 0.4741
#
# Epoch 00061: rmse improved from 0.47816 to 0.47692, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 62/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2247 - rmse: 0.4719
#
# Epoch 00062: rmse improved from 0.47692 to 0.47524, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 63/70
# 19743/19743 [==============================] - 157s 8ms/step - loss: 0.2244 - rmse: 0.4715
#
# Epoch 00063: rmse improved from 0.47524 to 0.47405, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 64/70
# 19743/19743 [==============================] - 160s 8ms/step - loss: 0.2231 - rmse: 0.4702
#
# Epoch 00064: rmse improved from 0.47405 to 0.47276, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 65/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2215 - rmse: 0.4685
#
# Epoch 00065: rmse improved from 0.47276 to 0.47131, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 66/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2207 - rmse: 0.4677
#
# Epoch 00066: rmse improved from 0.47131 to 0.47033, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 67/70
# 19743/19743 [==============================] - 154s 8ms/step - loss: 0.2192 - rmse: 0.4660
#
# Epoch 00067: rmse improved from 0.47033 to 0.46900, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 68/70
# 19743/19743 [==============================] - 155s 8ms/step - loss: 0.2178 - rmse: 0.4646
#
# Epoch 00068: rmse improved from 0.46900 to 0.46747, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 69/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2161 - rmse: 0.4628
#
# Epoch 00069: rmse improved from 0.46747 to 0.46625, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 70/70
# 19743/19743 [==============================] - 156s 8ms/step - loss: 0.2162 - rmse: 0.4629
#
# Epoch 00070: rmse improved from 0.46625 to 0.46508, saving model to /content/drive/MyDrive/model_ann.h5
