# %%
# !pip install meteocalc
# Out:
# Requirement already satisfied: meteocalc in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#!cp /content/drive/MyDrive/ashrae.zip ashrae.zip
#!unzip -q ashrae.zip

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import gc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.figure_factory as ff

from IPython.core.pylabtools import figsize
from plotly.offline import init_notebook_mode,iplot,plot
# %matplotlib inline
init_notebook_mode(connected=True)
plt.style.use("ggplot")
from sklearn.utils import shuffle

from sklearn.preprocessing import  LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

from keras.models import load_model
from keras.models import Model 
from keras.layers import Input, Dense, Lambda
from keras.layers import Embedding, Flatten, Dropout, Add, Activation
from keras.optimizers import Adam 
from keras.callbacks import ModelCheckpoint,EarlyStopping
import keras.backend as K

# importer les fichiers .py sur le notebook
# %run utils.py
# %run feature_enginering.py
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
building = pd.read_csv('/content/building_metadata.csv')
weather = pd.read_csv('/content/weather_train.csv')
train = pd.read_csv('/content/train.csv')

train.loc[(train.meter == 0),'meter_reading'] = train['meter_reading'] * 0.2931 # convertir du kwh vers kbtu

# %%
def join_data(data , weather_data , building_data):
    building_data = reduce_mem_usage(building_data)
    weather_data  = reduce_mem_usage(weather_data)
    data = reduce_mem_usage(data)

    weather_data = prepare_weather_data(weather_data)
    building_data = prepare_building_data(building_data)
    data  = time_features(data)
    
    data = data.merge(building_data, left_on = "building_id", right_on = "building_id", how = "left")
    data = data.merge(weather_data, left_on = ["site_id", "timestamp"], right_on = ["site_id", "timestamp"])

    data = shuffle(data, random_state=0)
    
    data = reduce_mem_usage(data)
    return data

# %%
train = join_data(train , weather , building)

train['log_meter_reading'] = np.log(train['meter_reading'] + 1)
train['month_group'] = train['month_group'] - 1

train = train.drop(['meter_reading'] , axis= 1)

del weather, building
gc.collect()
# Out:
# Memory usage of dataframe is 0.07 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 65.4%
# Memory usage of dataframe is 9.60 MB
# Memory usage after optimization is: 4.51 MB
# Decreased by 53.0%
# Memory usage of dataframe is 616.95 MB
# Memory usage after optimization is: 173.90 MB
# Decreased by 71.8%
# Memory usage of dataframe is 2361.15 MB
# Memory usage after optimization is: 1401.49 MB
# Decreased by 40.6%
# 49

# %%
print(len(train.columns))
print(train.columns)
print(train.shape)
# Out:
# 24
# Index(['building_id', 'meter', 'timestamp', 'hour', 'dayofweek', 'month_group',
#        'site_id', 'primary_use', 'square_feet', 'year_built', 'floor_count',
#        'air_temperature', 'cloud_coverage', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'relative_humidity', 'feels_like', 'city', 'country',
#        'is_holiday', 'log_meter_reading'],
#       dtype='object')
# (20125605, 24)

# %%
cols_to_drop = ['year_built' , 'floor_count' , 'timestamp']

cols_to_scale = ['square_feet' , 'air_temperature' , 'dew_temperature' ,
                 'wind_speed', 'cloud_coverage', 'sea_level_pressure', 'wind_direction',
                 'relative_humidity', 'feels_like']

cols_to_encode = ['primary_use' , 'city' , 'country']

ScalerEncoder = Data_Scaler_Encoder(cols_to_scale , cols_to_drop , cols_to_encode)
ScalerEncoder.fit(train)
train = ScalerEncoder.transform(train)

# %%
for col in train.columns:
  if train[col].isnull().values.any():
    print(col , 'il y a', train[col].isnull().values.sum() , ' Nan ')

# %%
def residual_block(input_x, nodes):
    d1 = Dense(nodes,activation='relu')(input_x)
    d2 = Dense(nodes,activation='relu')(d1)

    projected_x = Dense(nodes,activation='relu')(input_x)

    add = Add()([projected_x , d2])
    return add

def create_model(data , categorical_vars , numerical_vars):
    categ_inputs = []
    embed_layers = []  
    for col in categorical_vars:
        num_classes = len(np.unique(data[col]))

        input_x = Input(shape = [1] , name = col)
        categ_inputs.append(input_x)

        embed_x = Embedding(num_classes, 2)(input_x)
        embed_layers.append(embed_x)

    num_inputs = []
    for col in numerical_vars:
        num_inputs.append(Input(shape=[1] , name = col))

    concat_emb = K.concatenate([Flatten()(emb_layer) for emb_layer in embed_layers])

    d1 = residual_block(concat_emb , 512)
    main = K.concatenate(num_inputs+[d1])

    d2 = residual_block(main , 512)
    d3 = residual_block(d2 , 8)
    df = Dense(4 , name='second_to_last_layer')(d3)

    output = Dense(1 )(df)
    model  = Model(categ_inputs + num_inputs, output)

    return model 

def rmse(y_true, y_pred):
    """ root_mean_squared_error """
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
train.head()
# Out:
#           building_id  meter  hour  ...  country  is_holiday  log_meter_reading
# 2217631            79      0    16  ...        3           0           0.000000
# 14843430           43      1    17  ...        3           0           6.688351
# 17098627          769      2    18  ...        3           0           4.678588
# 10198113          774      0     8  ...        3           0           2.558731
# 15314118         1040      0     0  ...        0           0           3.926159
#
# [5 rows x 21 columns]

# %%
categorical_vars = ['building_id' , 'meter', 'hour', 'dayofweek' , 'month_group', 'site_id' , 
                    'primary_use', 'city', 'country', 'is_holiday']
                    
numerical_vars = ['square_feet', 'air_temperature', 'cloud_coverage', 'dew_temperature',
                  'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed', 
                  'relative_humidity' , 'feels_like']

target_var = 'log_meter_reading'

model = create_model(train, categorical_vars, numerical_vars)

# %%
y = train[target_var].values
y = y.reshape((len(y) , 1))

train = train.drop( [target_var] , axis = 1)

co_vars = categorical_vars + numerical_vars
train = train[co_vars].values

train = [ train[:,i].flatten() for i in range(len(train[0,:])) ]

# %%
checkpoint = ModelCheckpoint( '/content/drive/MyDrive/model_ann.h5', 
                                monitor='loss', 
                                verbose=1, 
                                save_best_only=True, 
                                mode='min')

early_stopping = EarlyStopping(patience = 5 ,monitor = "rmse")
callbacks_list = [checkpoint , early_stopping]

model.compile(optimizer = Adam(lr=1e-4), loss = 'mse',  metrics = [rmse])
history = model.fit(train, y, epochs = 65, batch_size = 1024, callbacks = callbacks_list)
# Out:
# Epoch 1/65
# 19654/19654 [==============================] - 380s 19ms/step - loss: 1.5029 - rmse: 1.1664
#
# Epoch 00001: loss improved from inf to 1.04235, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 2/65
# 19654/19654 [==============================] - 374s 19ms/step - loss: 0.7778 - rmse: 0.8799
#
# Epoch 00002: loss improved from 1.04235 to 0.75709, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 3/65
# 19654/19654 [==============================] - 375s 19ms/step - loss: 0.7074 - rmse: 0.8390
#
# Epoch 00003: loss improved from 0.75709 to 0.69531, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 4/65
# 19654/19654 [==============================] - 372s 19ms/step - loss: 0.6601 - rmse: 0.8104
#
# Epoch 00004: loss improved from 0.69531 to 0.64834, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 5/65
# 19654/19654 [==============================] - 368s 19ms/step - loss: 0.6182 - rmse: 0.7842
#
# Epoch 00005: loss improved from 0.64834 to 0.60932, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 6/65
# 19654/19654 [==============================] - 367s 19ms/step - loss: 0.5834 - rmse: 0.7617
#
# Epoch 00006: loss improved from 0.60932 to 0.57743, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 7/65
# 19654/19654 [==============================] - 364s 19ms/step - loss: 0.5569 - rmse: 0.7440
#
# Epoch 00007: loss improved from 0.57743 to 0.55082, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 8/65
# 19654/19654 [==============================] - 365s 19ms/step - loss: 0.5321 - rmse: 0.7272
#
# Epoch 00008: loss improved from 0.55082 to 0.52866, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 9/65
# 19654/19654 [==============================] - 366s 19ms/step - loss: 0.5150 - rmse: 0.7154
#
# Epoch 00009: loss improved from 0.52866 to 0.51129, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 10/65
# 19654/19654 [==============================] - 366s 19ms/step - loss: 0.4993 - rmse: 0.7043
#
# Epoch 00010: loss improved from 0.51129 to 0.49589, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 11/65
# 19654/19654 [==============================] - 363s 18ms/step - loss: 0.4836 - rmse: 0.6931
#
# Epoch 00011: loss improved from 0.49589 to 0.48134, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 12/65
# 19654/19654 [==============================] - 367s 19ms/step - loss: 0.4697 - rmse: 0.6831
#
# Epoch 00012: loss improved from 0.48134 to 0.46866, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 13/65
# 19654/19654 [==============================] - 367s 19ms/step - loss: 0.4589 - rmse: 0.6751
#
# Epoch 00013: loss improved from 0.46866 to 0.45752, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 14/65
# 19654/19654 [==============================] - 359s 18ms/step - loss: 0.4487 - rmse: 0.6675
#
# Epoch 00014: loss improved from 0.45752 to 0.44820, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 15/65
# 19654/19654 [==============================] - 360s 18ms/step - loss: 0.4409 - rmse: 0.6616
#
# Epoch 00015: loss improved from 0.44820 to 0.43984, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 16/65
# 19654/19654 [==============================] - 357s 18ms/step - loss: 0.4324 - rmse: 0.6552
#
# Epoch 00016: loss improved from 0.43984 to 0.43224, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 17/65
# 19654/19654 [==============================] - 358s 18ms/step - loss: 0.4256 - rmse: 0.6499
#
# Epoch 00017: loss improved from 0.43224 to 0.42572, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 18/65
# 19654/19654 [==============================] - 365s 19ms/step - loss: 0.4188 - rmse: 0.6447
#
# Epoch 00018: loss improved from 0.42572 to 0.41916, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 19/65
# 19654/19654 [==============================] - 362s 18ms/step - loss: 0.4132 - rmse: 0.6404
#
# Epoch 00019: loss improved from 0.41916 to 0.41334, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 20/65
# 19654/19654 [==============================] - 356s 18ms/step - loss: 0.4084 - rmse: 0.6366
#
# Epoch 00020: loss improved from 0.41334 to 0.40795, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 21/65
# 19654/19654 [==============================] - 358s 18ms/step - loss: 0.4029 - rmse: 0.6323
#
# Epoch 00021: loss improved from 0.40795 to 0.40280, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 22/65
# 19654/19654 [==============================] - 364s 19ms/step - loss: 0.3974 - rmse: 0.6280
#
# Epoch 00022: loss improved from 0.40280 to 0.39790, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 23/65
# 19654/19654 [==============================] - 371s 19ms/step - loss: 0.3933 - rmse: 0.6247
#
# Epoch 00023: loss improved from 0.39790 to 0.39331, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 24/65
# 19654/19654 [==============================] - 374s 19ms/step - loss: 0.3880 - rmse: 0.6205
#
# Epoch 00024: loss improved from 0.39331 to 0.38880, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 25/65
# 19654/19654 [==============================] - 362s 18ms/step - loss: 0.3837 - rmse: 0.6170
#
# Epoch 00025: loss improved from 0.38880 to 0.38481, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 26/65
# 19654/19654 [==============================] - 353s 18ms/step - loss: 0.3798 - rmse: 0.6138
#
# Epoch 00026: loss improved from 0.38481 to 0.38078, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 27/65
# 19654/19654 [==============================] - 352s 18ms/step - loss: 0.3760 - rmse: 0.6108
#
# Epoch 00027: loss improved from 0.38078 to 0.37707, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 28/65
# 19654/19654 [==============================] - 347s 18ms/step - loss: 0.3727 - rmse: 0.6080
#
# Epoch 00028: loss improved from 0.37707 to 0.37345, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 29/65
# 19654/19654 [==============================] - 347s 18ms/step - loss: 0.3693 - rmse: 0.6053
#
# Epoch 00029: loss improved from 0.37345 to 0.36986, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 30/65
# 19654/19654 [==============================] - 342s 17ms/step - loss: 0.3667 - rmse: 0.6031
#
# Epoch 00030: loss improved from 0.36986 to 0.36643, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 31/65
# 19654/19654 [==============================] - 329s 17ms/step - loss: 0.3619 - rmse: 0.5991
#
# Epoch 00031: loss improved from 0.36643 to 0.36317, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 32/65
# 19654/19654 [==============================] - 331s 17ms/step - loss: 0.3593 - rmse: 0.5970
#
# Epoch 00032: loss improved from 0.36317 to 0.36035, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 33/65
# 19654/19654 [==============================] - 340s 17ms/step - loss: 0.3556 - rmse: 0.5939
#
# Epoch 00033: loss improved from 0.36035 to 0.35702, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 34/65
# 19654/19654 [==============================] - 333s 17ms/step - loss: 0.3531 - rmse: 0.5918
#
# Epoch 00034: loss improved from 0.35702 to 0.35442, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 35/65
# 19654/19654 [==============================] - 332s 17ms/step - loss: 0.3492 - rmse: 0.5885
#
# Epoch 00035: loss improved from 0.35442 to 0.35126, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 36/65
# 19654/19654 [==============================] - 331s 17ms/step - loss: 0.3471 - rmse: 0.5866
#
# Epoch 00036: loss improved from 0.35126 to 0.34841, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 37/65
# 19654/19654 [==============================] - 332s 17ms/step - loss: 0.3443 - rmse: 0.5843
#
# Epoch 00037: loss improved from 0.34841 to 0.34559, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 38/65
# 19654/19654 [==============================] - 330s 17ms/step - loss: 0.3417 - rmse: 0.5821
#
# Epoch 00038: loss improved from 0.34559 to 0.34310, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 39/65
# 19654/19654 [==============================] - 329s 17ms/step - loss: 0.3393 - rmse: 0.5800
#
# Epoch 00039: loss improved from 0.34310 to 0.34037, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 40/65
# 19654/19654 [==============================] - 330s 17ms/step - loss: 0.3368 - rmse: 0.5779
#
# Epoch 00040: loss improved from 0.34037 to 0.33812, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 41/65
# 19654/19654 [==============================] - 328s 17ms/step - loss: 0.3337 - rmse: 0.5752
#
# Epoch 00041: loss improved from 0.33812 to 0.33550, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 42/65
# 19654/19654 [==============================] - 327s 17ms/step - loss: 0.3320 - rmse: 0.5738
#
# Epoch 00042: loss improved from 0.33550 to 0.33320, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 43/65
# 19654/19654 [==============================] - 322s 16ms/step - loss: 0.3294 - rmse: 0.5714
#
# Epoch 00043: loss improved from 0.33320 to 0.33103, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 44/65
# 19654/19654 [==============================] - 322s 16ms/step - loss: 0.3278 - rmse: 0.5701
#
# Epoch 00044: loss improved from 0.33103 to 0.32849, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 45/65
# 19654/19654 [==============================] - 324s 16ms/step - loss: 0.3254 - rmse: 0.5680
#
# Epoch 00045: loss improved from 0.32849 to 0.32668, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 46/65
# 19654/19654 [==============================] - 318s 16ms/step - loss: 0.3236 - rmse: 0.5664
#
# Epoch 00046: loss improved from 0.32668 to 0.32447, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 47/65
# 19654/19654 [==============================] - 335s 17ms/step - loss: 0.3211 - rmse: 0.5642
#
# Epoch 00047: loss improved from 0.32447 to 0.32218, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 48/65
# 19654/19654 [==============================] - 347s 18ms/step - loss: 0.3194 - rmse: 0.5626
#
# Epoch 00048: loss improved from 0.32218 to 0.32037, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 49/65
# 19654/19654 [==============================] - 345s 18ms/step - loss: 0.3172 - rmse: 0.5608
#
# Epoch 00049: loss improved from 0.32037 to 0.31799, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 50/65
# 19654/19654 [==============================] - 339s 17ms/step - loss: 0.3146 - rmse: 0.5585
#
# Epoch 00050: loss improved from 0.31799 to 0.31651, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 51/65
# 19654/19654 [==============================] - 339s 17ms/step - loss: 0.3128 - rmse: 0.5568
#
# Epoch 00051: loss improved from 0.31651 to 0.31489, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 52/65
# 19654/19654 [==============================] - 344s 18ms/step - loss: 0.3105 - rmse: 0.5547
#
# Epoch 00052: loss improved from 0.31489 to 0.31264, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 53/65
# 19654/19654 [==============================] - 344s 17ms/step - loss: 0.3093 - rmse: 0.5537
#
# Epoch 00053: loss improved from 0.31264 to 0.31110, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 54/65
# 19654/19654 [==============================] - 343s 17ms/step - loss: 0.3072 - rmse: 0.5517
#
# Epoch 00054: loss improved from 0.31110 to 0.30900, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 55/65
# 19654/19654 [==============================] - 358s 18ms/step - loss: 0.3059 - rmse: 0.5505
#
# Epoch 00055: loss improved from 0.30900 to 0.30749, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 56/65
# 19654/19654 [==============================] - 339s 17ms/step - loss: 0.3040 - rmse: 0.5488
#
# Epoch 00056: loss improved from 0.30749 to 0.30569, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 57/65
# 19654/19654 [==============================] - 326s 17ms/step - loss: 0.3024 - rmse: 0.5474
#
# Epoch 00057: loss improved from 0.30569 to 0.30406, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 58/65
# 19654/19654 [==============================] - 323s 16ms/step - loss: 0.3010 - rmse: 0.5461
#
# Epoch 00058: loss improved from 0.30406 to 0.30272, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 59/65
# 19654/19654 [==============================] - 317s 16ms/step - loss: 0.3001 - rmse: 0.5453
#
# Epoch 00059: loss improved from 0.30272 to 0.30114, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 60/65
# 19654/19654 [==============================] - 317s 16ms/step - loss: 0.2968 - rmse: 0.5423
#
# Epoch 00060: loss improved from 0.30114 to 0.29901, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 61/65
# 19654/19654 [==============================] - 321s 16ms/step - loss: 0.2962 - rmse: 0.5418
#
# Epoch 00061: loss improved from 0.29901 to 0.29780, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 62/65
# 19654/19654 [==============================] - 318s 16ms/step - loss: 0.2947 - rmse: 0.5404
#
# Epoch 00062: loss improved from 0.29780 to 0.29650, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 63/65
# 19654/19654 [==============================] - 321s 16ms/step - loss: 0.2933 - rmse: 0.5391
#
# Epoch 00063: loss improved from 0.29650 to 0.29501, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 64/65
# 19654/19654 [==============================] - 323s 16ms/step - loss: 0.2913 - rmse: 0.5372
#
# Epoch 00064: loss improved from 0.29501 to 0.29338, saving model to /content/drive/MyDrive/model_ann.h5
# Epoch 65/65
# 19654/19654 [==============================] - 320s 16ms/step - loss: 0.2895 - rmse: 0.5356
#
# Epoch 00065: loss improved from 0.29338 to 0.29175, saving model to /content/drive/MyDrive/model_ann.h5

# %% [markdown]
# * le modele a ete enregistre dans un fichier .h5 , ce ficiher va etre utilise dans un autre notebook pour faire la prediction.
